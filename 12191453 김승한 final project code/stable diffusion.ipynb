# %%
# !git clone https://github.com/seunghan11/stable-diffusion.git
# %pip install omegaconf
# %pip install invisible-watermark
# %pip install einops
# %pip install pytorch_lightning
# %pip install diffusers
# %pip install taming-transformers
# %pip install clip
# %pip install kornia
# Out:
# Cloning into 'stable-diffusion'...
# remote: Enumerating objects: 379, done.
# remote: Counting objects: 100% (38/38), done.
# remote: Compressing objects: 100% (30/30), done.
# remote: Total 379 (delta 16), reused 21 (delta 8), pack-reused 341
# Receiving objects: 100% (379/379), 42.67 MiB | 40.65 MiB/s, done.
# Resolving deltas: 100% (131/131), done.
# Collecting omegaconf
#   Downloading omegaconf-2.3.0-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 1.1 MB/s eta 0:00:00
# Collecting antlr4-python3-runtime==4.9.* (from omegaconf)
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 2.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: PyYAML>=5.1.0 in /usr/local/lib/python3.10/dist-packages (from omegaconf) (6.0.1)
# Building wheels for collected packages: antlr4-python3-runtime
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144554 sha256=44a078bf244e8734088e71821b8705b3cd893afed9c10e3a7693a95472cae2c0
#   Stored in directory: /root/.cache/pip/wheels/12/93/dd/1f6a127edc45659556564c5730f6d4e300888f4bca2d4c5a88
# Successfully built antlr4-python3-runtime
# Installing collected packages: antlr4-python3-runtime, omegaconf
# Successfully installed antlr4-python3-runtime-4.9.3 omegaconf-2.3.0
# Collecting invisible-watermark
#   Downloading invisible_watermark-0.2.0-py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 7.5 MB/s eta 0:00:00
# Requirement already satisfied: Pillow>=6.0.0 in /usr/local/lib/python3.10/dist-packages (from invisible-watermark) (9.4.0)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from invisible-watermark) (1.5.0)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from invisible-watermark) (1.23.5)
# Requirement already satisfied: opencv-python>=4.1.0.25 in /usr/local/lib/python3.10/dist-packages (from invisible-watermark) (4.8.0.76)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from invisible-watermark) (2.1.0+cu118)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->invisible-watermark) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch->invisible-watermark) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->invisible-watermark) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->invisible-watermark) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->invisible-watermark) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->invisible-watermark) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch->invisible-watermark) (2.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->invisible-watermark) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->invisible-watermark) (1.3.0)
# Installing collected packages: invisible-watermark
# Successfully installed invisible-watermark-0.2.0
# Collecting einops
#   Downloading einops-0.7.0-py3-none-any.whl (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 809.8 kB/s eta 0:00:00
# Installing collected packages: einops
# Successfully installed einops-0.7.0
# Collecting pytorch_lightning
#   Downloading pytorch_lightning-2.1.2-py3-none-any.whl (776 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 776.9/776.9 kB 4.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17.2 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (1.23.5)
# Requirement already satisfied: torch>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (2.1.0+cu118)
# Requirement already satisfied: tqdm>=4.57.0 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (4.66.1)
# Requirement already satisfied: PyYAML>=5.4 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (6.0.1)
# Requirement already satisfied: fsspec[http]>2021.06.0 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (2023.6.0)
# Collecting torchmetrics>=0.7.0 (from pytorch_lightning)
#   Downloading torchmetrics-1.2.1-py3-none-any.whl (806 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 806.1/806.1 kB 32.7 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (23.2)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (4.5.0)
# Collecting lightning-utilities>=0.8.0 (from pytorch_lightning)
#   Downloading lightning_utilities-0.10.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from fsspec[http]>2021.06.0->pytorch_lightning) (2.31.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]>2021.06.0->pytorch_lightning) (3.9.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from lightning-utilities>=0.8.0->pytorch_lightning) (67.7.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.12.0->pytorch_lightning) (3.13.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.12.0->pytorch_lightning) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.12.0->pytorch_lightning) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.12.0->pytorch_lightning) (3.1.2)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.12.0->pytorch_lightning) (2.1.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch_lightning) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch_lightning) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch_lightning) (1.9.3)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch_lightning) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch_lightning) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch_lightning) (4.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.12.0->pytorch_lightning) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->fsspec[http]>2021.06.0->pytorch_lightning) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->fsspec[http]>2021.06.0->pytorch_lightning) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->fsspec[http]>2021.06.0->pytorch_lightning) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->fsspec[http]>2021.06.0->pytorch_lightning) (2023.11.17)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.12.0->pytorch_lightning) (1.3.0)
# Installing collected packages: lightning-utilities, torchmetrics, pytorch_lightning
# Successfully installed lightning-utilities-0.10.0 pytorch_lightning-2.1.2 torchmetrics-1.2.1
# Collecting diffusers
#   Downloading diffusers-0.24.0-py3-none-any.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 7.8 MB/s eta 0:00:00
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from diffusers) (9.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from diffusers) (3.13.1)
# Requirement already satisfied: huggingface-hub>=0.19.4 in /usr/local/lib/python3.10/dist-packages (from diffusers) (0.19.4)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.10/dist-packages (from diffusers) (7.0.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from diffusers) (1.23.5)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from diffusers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from diffusers) (2.31.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from diffusers) (0.4.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.4->diffusers) (2023.6.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.4->diffusers) (4.66.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.4->diffusers) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.4->diffusers) (4.5.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.4->diffusers) (23.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata->diffusers) (3.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers) (2023.11.17)
# Installing collected packages: diffusers
# Successfully installed diffusers-0.24.0
# Collecting taming-transformers
#   Downloading taming_transformers-0.0.1-py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.6/45.6 kB 938.5 kB/s eta 0:00:00
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from taming-transformers) (2.1.0+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from taming-transformers) (0.16.0+cu118)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from taming-transformers) (1.23.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from taming-transformers) (4.66.1)
# Requirement already satisfied: omegaconf>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from taming-transformers) (2.3.0)
# Requirement already satisfied: pytorch-lightning>=1.0.8 in /usr/local/lib/python3.10/dist-packages (from taming-transformers) (2.1.2)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.10/dist-packages (from omegaconf>=2.0.0->taming-transformers) (4.9.3)
# Requirement already satisfied: PyYAML>=5.1.0 in /usr/local/lib/python3.10/dist-packages (from omegaconf>=2.0.0->taming-transformers) (6.0.1)
# Requirement already satisfied: fsspec[http]>2021.06.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning>=1.0.8->taming-transformers) (2023.6.0)
# Requirement already satisfied: torchmetrics>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning>=1.0.8->taming-transformers) (1.2.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning>=1.0.8->taming-transformers) (23.2)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning>=1.0.8->taming-transformers) (4.5.0)
# Requirement already satisfied: lightning-utilities>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning>=1.0.8->taming-transformers) (0.10.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->taming-transformers) (3.13.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->taming-transformers) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->taming-transformers) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->taming-transformers) (3.1.2)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch->taming-transformers) (2.1.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchvision->taming-transformers) (2.31.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->taming-transformers) (9.4.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]>2021.06.0->pytorch-lightning>=1.0.8->taming-transformers) (3.9.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from lightning-utilities>=0.8.0->pytorch-lightning>=1.0.8->taming-transformers) (67.7.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->taming-transformers) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision->taming-transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision->taming-transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision->taming-transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision->taming-transformers) (2023.11.17)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->taming-transformers) (1.3.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning>=1.0.8->taming-transformers) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning>=1.0.8->taming-transformers) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning>=1.0.8->taming-transformers) (1.9.3)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning>=1.0.8->taming-transformers) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning>=1.0.8->taming-transformers) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning>=1.0.8->taming-transformers) (4.0.3)
# Installing collected packages: taming-transformers
# Successfully installed taming-transformers-0.0.1
# Collecting clip
#   Downloading clip-0.2.0.tar.gz (5.5 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: clip
#   Building wheel for clip (setup.py) ... done
#   Created wheel for clip: filename=clip-0.2.0-py3-none-any.whl size=6989 sha256=5df620acc771d2e7da44e1189211532b9babe15b52ebfa6c7930690a99c8d945
#   Stored in directory: /root/.cache/pip/wheels/7f/5c/e6/2c0fdb453a3569188864b17e9676bea8b3b7e160c037117869
# Successfully built clip
# Installing collected packages: clip
# Successfully installed clip-0.2.0
# Collecting kornia
#   Downloading kornia-0.7.0-py2.py3-none-any.whl (705 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 705.7/705.7 kB 4.0 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from kornia) (23.2)
# Requirement already satisfied: torch>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from kornia) (2.1.0+cu118)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.1->kornia) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.1->kornia) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.1->kornia) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.1->kornia) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.1->kornia) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.1->kornia) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.1->kornia) (2.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.9.1->kornia) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.9.1->kornia) (1.3.0)
# Installing collected packages: kornia
# Successfully installed kornia-0.7.0

# %%
# %mkdir -p models/ldm/stable-diffusion-v1/

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import shutil
import os

# 원본 파일 경로
source = '/content/drive/MyDrive/Colab Notebooks/DL_set3/sd-v1-4.ckpt'

# # 목적지 디렉토리 경로
# destination = 'models/ldm/stable-diffusion-v1'

# # 파일 이동
# shutil.move(source, os.path.join(destination, 'sd-v1-1.ckpt'))
# # 목적지 파일 경로
# destination_path = '/content/drive/MyDrive/Colab Notebooks/DL_set3/model.ckpt'

# # 파일 복사 및 이름 변경
# shutil.copyfile(source_path, destination_path)

destination = 'models/ldm/stable-diffusion-v1/model.ckpt'

shutil.copyfile(source, destination)
# Out:
# 'models/ldm/stable-diffusion-v1/model.ckpt'

# %%
# !python /content/stable-diffusion/scripts/txt2img.py --prompt "a photograph of a green banana" --plms
# Out:
# preprocessor_config.json: 100% 342/342 [00:00<00:00, 1.68MB/s]
# 2023-12-14 06:00:15.018474: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-14 06:00:15.018529: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-14 06:00:15.018572: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-14 06:00:16.867598: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /usr/local/lib/python3.10/dist-packages/transformers/models/clip/feature_extraction_clip.py:28: FutureWarning: The class CLIPFeatureExtractor is deprecated and will be removed in version 5 of Transformers. Please use CLIPImageProcessor instead.
#   warnings.warn(
# config.json: 100% 4.55k/4.55k [00:00<00:00, 13.4MB/s]
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["id2label"]` will be overriden.
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["bos_token_id"]` will be overriden.
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["eos_token_id"]` will be overriden.
# pytorch_model.bin: 100% 1.22G/1.22G [00:09<00:00, 133MB/s]
# Seed set to 42
# Loading model from models/ldm/stable-diffusion-v1/model.ckpt
# Global Step: 470000
# LatentDiffusion: Running in eps-prediction mode
# DiffusionWrapper has 859.52 M params.
# making attention of type 'vanilla' with 512 in_channels
# Working with z of shape (1, 4, 32, 32) = 4096 dimensions.
# making attention of type 'vanilla' with 512 in_channels
# tokenizer_config.json: 100% 905/905 [00:00<00:00, 4.96MB/s]
# vocab.json: 100% 961k/961k [00:00<00:00, 16.2MB/s]
# merges.txt: 100% 525k/525k [00:00<00:00, 15.5MB/s]
# special_tokens_map.json: 100% 389/389 [00:00<00:00, 3.23MB/s]
# tokenizer.json: 100% 2.22M/2.22M [00:00<00:00, 58.0MB/s]
# config.json: 100% 4.52k/4.52k [00:00<00:00, 23.1MB/s]
# model.safetensors: 100% 1.71G/1.71G [00:29<00:00, 58.1MB/s]
# Creating invisible watermark encoder (see https://github.com/ShieldMnt/invisible-watermark)...
# Sampling:   0% 0/2 [00:00<?, ?it/s]
# data:   0% 0/1 [00:00<?, ?it/s]Data shape for PLMS sampling is (3, 4, 64, 64)
# Running PLMS Sampling with 50 timesteps
#
#
# PLMS Sampler:   0% 0/50 [00:00<?, ?it/s]
#
# PLMS Sampler:   2% 1/50 [00:02<01:38,  2.02s/it]
#
# PLMS Sampler:   4% 2/50 [00:02<00:46,  1.03it/s]
#
# PLMS Sampler:   6% 3/50 [00:02<00:29,  1.59it/s]
#
# PLMS Sampler:   8% 4/50 [00:02<00:21,  2.11it/s]
#
# PLMS Sampler:  10% 5/50 [00:02<00:17,  2.59it/s]
#
# PLMS Sampler:  12% 6/50 [00:03<00:14,  3.00it/s]
#
# PLMS Sampler:  14% 7/50 [00:03<00:12,  3.33it/s]
#
# PLMS Sampler:  16% 8/50 [00:03<00:11,  3.59it/s]
#
# PLMS Sampler:  18% 9/50 [00:03<00:10,  3.79it/s]
#
# PLMS Sampler:  20% 10/50 [00:04<00:10,  3.94it/s]
#
# PLMS Sampler:  22% 11/50 [00:04<00:09,  4.05it/s]
#
# PLMS Sampler:  24% 12/50 [00:04<00:09,  4.14it/s]
#
# PLMS Sampler:  26% 13/50 [00:04<00:08,  4.20it/s]
#
# PLMS Sampler:  28% 14/50 [00:05<00:08,  4.25it/s]
#
# PLMS Sampler:  30% 15/50 [00:05<00:08,  4.28it/s]
#
# PLMS Sampler:  32% 16/50 [00:05<00:07,  4.29it/s]
#
# PLMS Sampler:  34% 17/50 [00:05<00:07,  4.32it/s]
#
# PLMS Sampler:  36% 18/50 [00:05<00:07,  4.33it/s]
#
# PLMS Sampler:  38% 19/50 [00:06<00:07,  4.33it/s]
#
# PLMS Sampler:  40% 20/50 [00:06<00:06,  4.33it/s]
#
# PLMS Sampler:  42% 21/50 [00:06<00:06,  4.32it/s]
#
# PLMS Sampler:  44% 22/50 [00:06<00:06,  4.32it/s]
#
# PLMS Sampler:  46% 23/50 [00:07<00:06,  4.33it/s]
#
# PLMS Sampler:  48% 24/50 [00:07<00:06,  4.33it/s]
#
# PLMS Sampler:  50% 25/50 [00:07<00:05,  4.32it/s]
#
# PLMS Sampler:  52% 26/50 [00:07<00:05,  4.32it/s]
#
# PLMS Sampler:  54% 27/50 [00:08<00:05,  4.31it/s]
#
# PLMS Sampler:  56% 28/50 [00:08<00:05,  4.33it/s]
#
# PLMS Sampler:  58% 29/50 [00:08<00:04,  4.34it/s]
#
# PLMS Sampler:  60% 30/50 [00:08<00:04,  4.33it/s]
#
# PLMS Sampler:  62% 31/50 [00:08<00:04,  4.33it/s]
#
# PLMS Sampler:  64% 32/50 [00:09<00:04,  4.33it/s]
#
# PLMS Sampler:  66% 33/50 [00:09<00:03,  4.33it/s]
#
# PLMS Sampler:  68% 34/50 [00:09<00:03,  4.32it/s]
#
# PLMS Sampler:  70% 35/50 [00:09<00:03,  4.30it/s]
#
# PLMS Sampler:  72% 36/50 [00:10<00:03,  4.31it/s]
#
# PLMS Sampler:  74% 37/50 [00:10<00:03,  4.32it/s]
#
# PLMS Sampler:  76% 38/50 [00:10<00:02,  4.32it/s]
#
# PLMS Sampler:  78% 39/50 [00:10<00:02,  4.32it/s]
#
# PLMS Sampler:  80% 40/50 [00:11<00:02,  4.32it/s]
#
# PLMS Sampler:  82% 41/50 [00:11<00:02,  4.31it/s]
#
# PLMS Sampler:  84% 42/50 [00:11<00:01,  4.31it/s]
#
# PLMS Sampler:  86% 43/50 [00:11<00:01,  4.31it/s]
#
# PLMS Sampler:  88% 44/50 [00:11<00:01,  4.29it/s]
#
# PLMS Sampler:  90% 45/50 [00:12<00:01,  4.31it/s]
#
# PLMS Sampler:  92% 46/50 [00:12<00:00,  4.32it/s]
#
# PLMS Sampler:  94% 47/50 [00:12<00:00,  4.31it/s]
#
# PLMS Sampler:  96% 48/50 [00:12<00:00,  4.32it/s]
#
# PLMS Sampler:  98% 49/50 [00:13<00:00,  4.32it/s]
#
# PLMS Sampler: 100% 50/50 [00:13<00:00,  3.75it/s]
#
# data: 100% 1/1 [00:22<00:00, 22.37s/it]
# Sampling:  50% 1/2 [00:22<00:22, 22.37s/it]
# data:   0% 0/1 [00:00<?, ?it/s]Data shape for PLMS sampling is (3, 4, 64, 64)
# Running PLMS Sampling with 50 timesteps
#
#
# PLMS Sampler:   0% 0/50 [00:00<?, ?it/s]
#
# PLMS Sampler:   2% 1/50 [00:00<00:23,  2.12it/s]
#
# PLMS Sampler:   4% 2/50 [00:00<00:15,  3.02it/s]
#
# PLMS Sampler:   6% 3/50 [00:00<00:13,  3.51it/s]
#
# PLMS Sampler:   8% 4/50 [00:01<00:12,  3.80it/s]
#
# PLMS Sampler:  10% 5/50 [00:01<00:11,  3.97it/s]
#
# PLMS Sampler:  12% 6/50 [00:01<00:10,  4.10it/s]
#
# PLMS Sampler:  14% 7/50 [00:01<00:10,  4.18it/s]
#
# PLMS Sampler:  16% 8/50 [00:02<00:09,  4.23it/s]
#
# PLMS Sampler:  18% 9/50 [00:02<00:09,  4.26it/s]
#
# PLMS Sampler:  20% 10/50 [00:02<00:09,  4.28it/s]
#
# PLMS Sampler:  22% 11/50 [00:02<00:09,  4.29it/s]
#
# PLMS Sampler:  24% 12/50 [00:03<00:08,  4.29it/s]
#
# PLMS Sampler:  26% 13/50 [00:03<00:08,  4.29it/s]
#
# PLMS Sampler:  28% 14/50 [00:03<00:08,  4.29it/s]
#
# PLMS Sampler:  30% 15/50 [00:03<00:08,  4.30it/s]
#
# PLMS Sampler:  32% 16/50 [00:03<00:07,  4.31it/s]
#
# PLMS Sampler:  34% 17/50 [00:04<00:07,  4.32it/s]
#
# PLMS Sampler:  36% 18/50 [00:04<00:07,  4.30it/s]
#
# PLMS Sampler:  38% 19/50 [00:04<00:07,  4.30it/s]
#
# PLMS Sampler:  40% 20/50 [00:04<00:06,  4.31it/s]
#
# PLMS Sampler:  42% 21/50 [00:05<00:06,  4.33it/s]
#
# PLMS Sampler:  44% 22/50 [00:05<00:06,  4.31it/s]
#
# PLMS Sampler:  46% 23/50 [00:05<00:06,  4.31it/s]
#
# PLMS Sampler:  48% 24/50 [00:05<00:06,  4.31it/s]
#
# PLMS Sampler:  50% 25/50 [00:06<00:05,  4.31it/s]
#
# PLMS Sampler:  52% 26/50 [00:06<00:05,  4.30it/s]
#
# PLMS Sampler:  54% 27/50 [00:06<00:05,  4.30it/s]
#
# PLMS Sampler:  56% 28/50 [00:06<00:05,  4.31it/s]
#
# PLMS Sampler:  58% 29/50 [00:06<00:04,  4.30it/s]
#
# PLMS Sampler:  60% 30/50 [00:07<00:04,  4.32it/s]
#
# PLMS Sampler:  62% 31/50 [00:07<00:04,  4.32it/s]
#
# PLMS Sampler:  64% 32/50 [00:07<00:04,  4.31it/s]
#
# PLMS Sampler:  66% 33/50 [00:07<00:03,  4.30it/s]
#
# PLMS Sampler:  68% 34/50 [00:08<00:03,  4.29it/s]
#
# PLMS Sampler:  70% 35/50 [00:08<00:03,  4.30it/s]
#
# PLMS Sampler:  72% 36/50 [00:08<00:03,  4.31it/s]
#
# PLMS Sampler:  74% 37/50 [00:08<00:03,  4.30it/s]
#
# PLMS Sampler:  76% 38/50 [00:09<00:02,  4.31it/s]
#
# PLMS Sampler:  78% 39/50 [00:09<00:02,  4.32it/s]
#
# PLMS Sampler:  80% 40/50 [00:09<00:02,  4.32it/s]
#
# PLMS Sampler:  82% 41/50 [00:09<00:02,  4.32it/s]
#
# PLMS Sampler:  84% 42/50 [00:09<00:01,  4.31it/s]
#
# PLMS Sampler:  86% 43/50 [00:10<00:01,  4.31it/s]
#
# PLMS Sampler:  88% 44/50 [00:10<00:01,  4.32it/s]
#
# PLMS Sampler:  90% 45/50 [00:10<00:01,  4.32it/s]
#
# PLMS Sampler:  92% 46/50 [00:10<00:00,  4.33it/s]
#
# PLMS Sampler:  94% 47/50 [00:11<00:00,  4.33it/s]
#
# PLMS Sampler:  96% 48/50 [00:11<00:00,  4.33it/s]
#
# PLMS Sampler:  98% 49/50 [00:11<00:00,  4.33it/s]
#
# PLMS Sampler: 100% 50/50 [00:11<00:00,  4.23it/s]
#
# data: 100% 1/1 [00:19<00:00, 19.27s/it]
# Sampling: 100% 2/2 [00:41<00:00, 20.82s/it]
# Your samples are ready and waiting for you here:
# outputs/txt2img-samples
#
# Enjoy.

# %%
# !zip -r /content/aa.zip /content/stable-diffusion/
# Out:
#   adding: content/stable-diffusion/ (stored 0%)
#   adding: content/stable-diffusion/notebook_helpers.py (deflated 71%)
#   adding: content/stable-diffusion/environment.yaml (deflated 50%)
#   adding: content/stable-diffusion/README.md (deflated 60%)
#   adding: content/stable-diffusion/.git/ (stored 0%)
#   adding: content/stable-diffusion/.git/refs/ (stored 0%)
#   adding: content/stable-diffusion/.git/refs/tags/ (stored 0%)
#   adding: content/stable-diffusion/.git/refs/heads/ (stored 0%)
#   adding: content/stable-diffusion/.git/refs/heads/main (stored 0%)
#   adding: content/stable-diffusion/.git/refs/remotes/ (stored 0%)
#   adding: content/stable-diffusion/.git/refs/remotes/origin/ (stored 0%)
#   adding: content/stable-diffusion/.git/refs/remotes/origin/HEAD (stored 0%)
#   adding: content/stable-diffusion/.git/objects/ (stored 0%)
#   adding: content/stable-diffusion/.git/objects/pack/ (stored 0%)
#   adding: content/stable-diffusion/.git/objects/pack/pack-fb18e4a6fd6bcb54b776f7349b5475df479e8f44.idx (deflated 6%)
#   adding: content/stable-diffusion/.git/objects/pack/pack-fb18e4a6fd6bcb54b776f7349b5475df479e8f44.pack (deflated 3%)
#   adding: content/stable-diffusion/.git/objects/info/ (stored 0%)
#   adding: content/stable-diffusion/.git/HEAD (stored 0%)
#   adding: content/stable-diffusion/.git/hooks/ (stored 0%)
#   adding: content/stable-diffusion/.git/hooks/pre-push.sample (deflated 49%)
#   adding: content/stable-diffusion/.git/hooks/pre-rebase.sample (deflated 59%)
#   adding: content/stable-diffusion/.git/hooks/post-update.sample (deflated 27%)
#   adding: content/stable-diffusion/.git/hooks/prepare-commit-msg.sample (deflated 50%)
#   adding: content/stable-diffusion/.git/hooks/applypatch-msg.sample (deflated 42%)
#   adding: content/stable-diffusion/.git/hooks/pre-commit.sample (deflated 45%)
#   adding: content/stable-diffusion/.git/hooks/pre-merge-commit.sample (deflated 39%)
#   adding: content/stable-diffusion/.git/hooks/pre-receive.sample (deflated 40%)
#   adding: content/stable-diffusion/.git/hooks/push-to-checkout.sample (deflated 55%)
#   adding: content/stable-diffusion/.git/hooks/pre-applypatch.sample (deflated 38%)
#   adding: content/stable-diffusion/.git/hooks/commit-msg.sample (deflated 44%)
#   adding: content/stable-diffusion/.git/hooks/update.sample (deflated 68%)
#   adding: content/stable-diffusion/.git/hooks/fsmonitor-watchman.sample (deflated 62%)
#   adding: content/stable-diffusion/.git/branches/ (stored 0%)
#   adding: content/stable-diffusion/.git/config (deflated 33%)
#   adding: content/stable-diffusion/.git/description (deflated 14%)
#   adding: content/stable-diffusion/.git/logs/ (stored 0%)
#   adding: content/stable-diffusion/.git/logs/refs/ (stored 0%)
#   adding: content/stable-diffusion/.git/logs/refs/heads/ (stored 0%)
#   adding: content/stable-diffusion/.git/logs/refs/heads/main (deflated 27%)
#   adding: content/stable-diffusion/.git/logs/refs/remotes/ (stored 0%)
#   adding: content/stable-diffusion/.git/logs/refs/remotes/origin/ (stored 0%)
#   adding: content/stable-diffusion/.git/logs/refs/remotes/origin/HEAD (deflated 27%)
#   adding: content/stable-diffusion/.git/logs/HEAD (deflated 27%)
#   adding: content/stable-diffusion/.git/info/ (stored 0%)
#   adding: content/stable-diffusion/.git/info/exclude (deflated 28%)
#   adding: content/stable-diffusion/.git/packed-refs (deflated 10%)
#   adding: content/stable-diffusion/.git/index (deflated 54%)
#   adding: content/stable-diffusion/assets/ (stored 0%)
#   adding: content/stable-diffusion/assets/stable-samples/ (stored 0%)
#   adding: content/stable-diffusion/assets/stable-samples/img2img/ (stored 0%)
#   adding: content/stable-diffusion/assets/stable-samples/img2img/mountains-1.png (deflated 0%)
#   adding: content/stable-diffusion/assets/stable-samples/img2img/upscaling-out.png (deflated 0%)
#   adding: content/stable-diffusion/assets/stable-samples/img2img/upscaling-in.png (deflated 0%)
#   adding: content/stable-diffusion/assets/stable-samples/img2img/mountains-3.png (deflated 0%)
#   adding: content/stable-diffusion/assets/stable-samples/img2img/sketch-mountains-input.jpg (deflated 1%)
#   adding: content/stable-diffusion/assets/stable-samples/img2img/mountains-2.png (deflated 0%)
#   adding: content/stable-diffusion/assets/stable-samples/txt2img/ (stored 0%)
#   adding: content/stable-diffusion/assets/stable-samples/txt2img/000002035.png (deflated 0%)
#   adding: content/stable-diffusion/assets/stable-samples/txt2img/merged-0007.png (deflated 0%)
#   adding: content/stable-diffusion/assets/stable-samples/txt2img/merged-0006.png (deflated 0%)
#   adding: content/stable-diffusion/assets/stable-samples/txt2img/merged-0005.png (deflated 0%)
#   adding: content/stable-diffusion/assets/stable-samples/txt2img/000002025.png (deflated 0%)
#   adding: content/stable-diffusion/assets/results.gif (deflated 1%)
#   adding: content/stable-diffusion/assets/txt2img-preview.png (deflated 0%)
#   adding: content/stable-diffusion/assets/a-watercolor-painting-of-a-fire.png (deflated 0%)
#   adding: content/stable-diffusion/assets/rick.jpeg (deflated 5%)
#   adding: content/stable-diffusion/assets/reconstruction2.png (deflated 0%)
#   adding: content/stable-diffusion/assets/fire.png (deflated 0%)
#   adding: content/stable-diffusion/assets/v1-variants-scores.jpg (deflated 11%)
#   adding: content/stable-diffusion/assets/a-painting-of-a-fire.png (deflated 0%)
#   adding: content/stable-diffusion/assets/rdm-preview.jpg (deflated 10%)
#   adding: content/stable-diffusion/assets/txt2img-convsample.png (deflated 0%)
#   adding: content/stable-diffusion/assets/inpainting.png (deflated 0%)
#   adding: content/stable-diffusion/assets/reconstruction1.png (deflated 0%)
#   adding: content/stable-diffusion/assets/a-shirt-with-the-inscription-'fire'.png (deflated 0%)
#   adding: content/stable-diffusion/assets/birdhouse.png (deflated 0%)
#   adding: content/stable-diffusion/assets/modelfigure.png (deflated 0%)
#   adding: content/stable-diffusion/assets/a-photograph-of-a-fire.png (deflated 0%)
#   adding: content/stable-diffusion/assets/the-earth-is-on-fire,-oil-on-canvas.png (deflated 0%)
#   adding: content/stable-diffusion/assets/a-shirt-with-a-fire-printed-on-it.png (deflated 0%)
#   adding: content/stable-diffusion/scripts/ (stored 0%)
#   adding: content/stable-diffusion/scripts/txt2img.py (deflated 71%)
#   adding: content/stable-diffusion/scripts/download_models.sh (deflated 80%)
#   adding: content/stable-diffusion/scripts/img2img.py (deflated 68%)
#   adding: content/stable-diffusion/scripts/inpaint.py (deflated 65%)
#   adding: content/stable-diffusion/scripts/knn2img.py (deflated 71%)
#   adding: content/stable-diffusion/scripts/download_first_stages.sh (deflated 84%)
#   adding: content/stable-diffusion/scripts/latent_imagenet_diffusion.ipynb (deflated 25%)
#   adding: content/stable-diffusion/scripts/tests/ (stored 0%)
#   adding: content/stable-diffusion/scripts/tests/test_watermark.py (deflated 43%)
#   adding: content/stable-diffusion/scripts/train_searcher.py (deflated 68%)
#   adding: content/stable-diffusion/scripts/sample_diffusion.py (deflated 68%)
#   adding: content/stable-diffusion/data/ (stored 0%)
#   adding: content/stable-diffusion/data/imagenet_train_hr_indices.p (deflated 68%)
#   adding: content/stable-diffusion/data/imagenet_val_hr_indices.p (deflated 27%)
#   adding: content/stable-diffusion/data/imagenet_clsidx_to_label.txt (deflated 58%)
#   adding: content/stable-diffusion/data/inpainting_examples/ (stored 0%)
#   adding: content/stable-diffusion/data/inpainting_examples/photo-1583445095369-9c651e7e5d34_mask.png (deflated 2%)
#   adding: content/stable-diffusion/data/inpainting_examples/6458524847_2f4c361183_k.png (deflated 0%)
#   adding: content/stable-diffusion/data/inpainting_examples/bertrand-gabioud-CpuFzIsHYJ0.png (deflated 0%)
#   adding: content/stable-diffusion/data/inpainting_examples/8399166846_f6fb4e4b8e_k.png (deflated 0%)
#   adding: content/stable-diffusion/data/inpainting_examples/alex-iby-G_Pk4D9rMLs.png (deflated 0%)
#   adding: content/stable-diffusion/data/inpainting_examples/bench2.png (deflated 0%)
#   adding: content/stable-diffusion/data/inpainting_examples/6458524847_2f4c361183_k_mask.png (deflated 2%)
#   adding: content/stable-diffusion/data/inpainting_examples/bench2_mask.png (deflated 5%)
#   adding: content/stable-diffusion/data/inpainting_examples/alex-iby-G_Pk4D9rMLs_mask.png (deflated 1%)
#   adding: content/stable-diffusion/data/inpainting_examples/photo-1583445095369-9c651e7e5d34.png (deflated 0%)
#   adding: content/stable-diffusion/data/inpainting_examples/billow926-12-Wc-Zgx6Y.png (deflated 0%)
#   adding: content/stable-diffusion/data/inpainting_examples/billow926-12-Wc-Zgx6Y_mask.png (deflated 3%)
#   adding: content/stable-diffusion/data/inpainting_examples/bertrand-gabioud-CpuFzIsHYJ0_mask.png (deflated 4%)
#   adding: content/stable-diffusion/data/inpainting_examples/8399166846_f6fb4e4b8e_k_mask.png (deflated 3%)
#   adding: content/stable-diffusion/data/inpainting_examples/overture-creations-5sI6fQgYIuo_mask.png (deflated 6%)
#   adding: content/stable-diffusion/data/inpainting_examples/overture-creations-5sI6fQgYIuo.png (deflated 0%)
#   adding: content/stable-diffusion/data/DejaVuSans.ttf (deflated 50%)
#   adding: content/stable-diffusion/data/example_conditioning/ (stored 0%)
#   adding: content/stable-diffusion/data/example_conditioning/superresolution/ (stored 0%)
#   adding: content/stable-diffusion/data/example_conditioning/superresolution/sample_0.jpg (deflated 2%)
#   adding: content/stable-diffusion/data/example_conditioning/text_conditional/ (stored 0%)
#   adding: content/stable-diffusion/data/example_conditioning/text_conditional/sample_0.txt (stored 0%)
#   adding: content/stable-diffusion/data/index_synset.yaml (deflated 60%)
#   adding: content/stable-diffusion/LICENSE (deflated 63%)
#   adding: content/stable-diffusion/Stable_Diffusion_v1_Model_Card.md (deflated 60%)
#   adding: content/stable-diffusion/configs/ (stored 0%)
#   adding: content/stable-diffusion/configs/autoencoder/ (stored 0%)
#   adding: content/stable-diffusion/configs/autoencoder/autoencoder_kl_64x64x3.yaml (deflated 55%)
#   adding: content/stable-diffusion/configs/autoencoder/autoencoder_kl_32x32x4.yaml (deflated 55%)
#   adding: content/stable-diffusion/configs/autoencoder/autoencoder_kl_8x8x64.yaml (deflated 54%)
#   adding: content/stable-diffusion/configs/autoencoder/autoencoder_kl_16x16x16.yaml (deflated 54%)
#   adding: content/stable-diffusion/configs/stable-diffusion/ (stored 0%)
#   adding: content/stable-diffusion/configs/stable-diffusion/v1-inference.yaml (deflated 60%)
#   adding: content/stable-diffusion/configs/latent-diffusion/ (stored 0%)
#   adding: content/stable-diffusion/configs/latent-diffusion/txt2img-1p4B-eval.yaml (deflated 63%)
#   adding: content/stable-diffusion/configs/latent-diffusion/lsun_bedrooms-ldm-vq-4.yaml (deflated 61%)
#   adding: content/stable-diffusion/configs/latent-diffusion/ffhq-ldm-vq-4.yaml (deflated 61%)
#   adding: content/stable-diffusion/configs/latent-diffusion/lsun_churches-ldm-kl-8.yaml (deflated 60%)
#   adding: content/stable-diffusion/configs/latent-diffusion/celebahq-ldm-vq-4.yaml (deflated 61%)
#   adding: content/stable-diffusion/configs/latent-diffusion/cin256-v2.yaml (deflated 64%)
#   adding: content/stable-diffusion/configs/latent-diffusion/cin-ldm-vq-f8.yaml (deflated 63%)
#   adding: content/stable-diffusion/configs/retrieval-augmented-diffusion/ (stored 0%)
#   adding: content/stable-diffusion/configs/retrieval-augmented-diffusion/768x768.yaml (deflated 64%)
#   adding: content/stable-diffusion/main.py (deflated 75%)
#   adding: content/stable-diffusion/ldm/ (stored 0%)
#   adding: content/stable-diffusion/ldm/data/ (stored 0%)
#   adding: content/stable-diffusion/ldm/data/lsun.py (deflated 72%)
#   adding: content/stable-diffusion/ldm/data/imagenet.py (deflated 75%)
#   adding: content/stable-diffusion/ldm/data/base.py (deflated 54%)
#   adding: content/stable-diffusion/ldm/data/__init__.py (stored 0%)
#   adding: content/stable-diffusion/ldm/lr_scheduler.py (deflated 80%)
#   adding: content/stable-diffusion/ldm/__pycache__/ (stored 0%)
#   adding: content/stable-diffusion/ldm/__pycache__/util.cpython-310.pyc (deflated 43%)
#   adding: content/stable-diffusion/ldm/models/ (stored 0%)
#   adding: content/stable-diffusion/ldm/models/diffusion/ (stored 0%)
#   adding: content/stable-diffusion/ldm/models/diffusion/ddpm.py (deflated 79%)
#   adding: content/stable-diffusion/ldm/models/diffusion/ddim.py (deflated 77%)
#   adding: content/stable-diffusion/ldm/models/diffusion/plms.py (deflated 76%)
#   adding: content/stable-diffusion/ldm/models/diffusion/__pycache__/ (stored 0%)
#   adding: content/stable-diffusion/ldm/models/diffusion/__pycache__/ddim.cpython-310.pyc (deflated 46%)
#   adding: content/stable-diffusion/ldm/models/diffusion/__pycache__/plms.cpython-310.pyc (deflated 46%)
#   adding: content/stable-diffusion/ldm/models/diffusion/__pycache__/__init__.cpython-310.pyc (deflated 28%)
#   adding: content/stable-diffusion/ldm/models/diffusion/__pycache__/ddpm.cpython-310.pyc (deflated 53%)
#   adding: content/stable-diffusion/ldm/models/diffusion/__init__.py (stored 0%)
#   adding: content/stable-diffusion/ldm/models/diffusion/classifier.py (deflated 71%)
#   adding: content/stable-diffusion/ldm/models/diffusion/dpm_solver/ (stored 0%)
#   adding: content/stable-diffusion/ldm/models/diffusion/dpm_solver/sampler.py (deflated 64%)
#   adding: content/stable-diffusion/ldm/models/diffusion/dpm_solver/__pycache__/ (stored 0%)
#   adding: content/stable-diffusion/ldm/models/diffusion/dpm_solver/__pycache__/dpm_solver.cpython-310.pyc (deflated 68%)
#   adding: content/stable-diffusion/ldm/models/diffusion/dpm_solver/__pycache__/__init__.cpython-310.pyc (deflated 22%)
#   adding: content/stable-diffusion/ldm/models/diffusion/dpm_solver/__pycache__/sampler.cpython-310.pyc (deflated 41%)
#   adding: content/stable-diffusion/ldm/models/diffusion/dpm_solver/__init__.py (deflated 5%)
#   adding: content/stable-diffusion/ldm/models/diffusion/dpm_solver/dpm_solver.py (deflated 81%)
#   adding: content/stable-diffusion/ldm/models/__pycache__/ (stored 0%)
#   adding: content/stable-diffusion/ldm/models/__pycache__/autoencoder.cpython-310.pyc (deflated 54%)
#   adding: content/stable-diffusion/ldm/models/autoencoder.py (deflated 81%)
#   adding: content/stable-diffusion/ldm/modules/ (stored 0%)
#   adding: content/stable-diffusion/ldm/modules/x_transformer.py (deflated 75%)
#   adding: content/stable-diffusion/ldm/modules/encoders/ (stored 0%)
#   adding: content/stable-diffusion/ldm/modules/encoders/__pycache__/ (stored 0%)
#   adding: content/stable-diffusion/ldm/modules/encoders/__pycache__/__init__.cpython-310.pyc (deflated 25%)
#   adding: content/stable-diffusion/ldm/modules/encoders/__pycache__/modules.cpython-310.pyc (deflated 56%)
#   adding: content/stable-diffusion/ldm/modules/encoders/__init__.py (stored 0%)
#   adding: content/stable-diffusion/ldm/modules/encoders/modules.py (deflated 72%)
#   adding: content/stable-diffusion/ldm/modules/diffusionmodules/ (stored 0%)
#   adding: content/stable-diffusion/ldm/modules/diffusionmodules/model.py (deflated 85%)
#   adding: content/stable-diffusion/ldm/modules/diffusionmodules/openaimodel.py (deflated 82%)
#   adding: content/stable-diffusion/ldm/modules/diffusionmodules/__pycache__/ (stored 0%)
#   adding: content/stable-diffusion/ldm/modules/diffusionmodules/__pycache__/model.cpython-310.pyc (deflated 57%)
#   adding: content/stable-diffusion/ldm/modules/diffusionmodules/__pycache__/openaimodel.cpython-310.pyc (deflated 58%)
#   adding: content/stable-diffusion/ldm/modules/diffusionmodules/__pycache__/util.cpython-310.pyc (deflated 50%)
#   adding: content/stable-diffusion/ldm/modules/diffusionmodules/__pycache__/__init__.cpython-310.pyc (deflated 31%)
#   adding: content/stable-diffusion/ldm/modules/diffusionmodules/__init__.py (stored 0%)
#   adding: content/stable-diffusion/ldm/modules/diffusionmodules/util.py (deflated 66%)
#   adding: content/stable-diffusion/ldm/modules/image_degradation/ (stored 0%)
#   adding: content/stable-diffusion/ldm/modules/image_degradation/bsrgan.py (deflated 75%)
#   adding: content/stable-diffusion/ldm/modules/image_degradation/bsrgan_light.py (deflated 73%)
#   adding: content/stable-diffusion/ldm/modules/image_degradation/utils/ (stored 0%)
#   adding: content/stable-diffusion/ldm/modules/image_degradation/utils/test.png (deflated 1%)
#   adding: content/stable-diffusion/ldm/modules/image_degradation/__init__.py (deflated 60%)
#   adding: content/stable-diffusion/ldm/modules/image_degradation/utils_image.py (deflated 77%)
#   adding: content/stable-diffusion/ldm/modules/attention.py (deflated 74%)
#   adding: content/stable-diffusion/ldm/modules/distributions/ (stored 0%)
#   adding: content/stable-diffusion/ldm/modules/distributions/distributions.py (deflated 66%)
#   adding: content/stable-diffusion/ldm/modules/distributions/__pycache__/ (stored 0%)
#   adding: content/stable-diffusion/ldm/modules/distributions/__pycache__/__init__.cpython-310.pyc (deflated 24%)
#   adding: content/stable-diffusion/ldm/modules/distributions/__pycache__/distributions.cpython-310.pyc (deflated 51%)
#   adding: content/stable-diffusion/ldm/modules/distributions/__init__.py (stored 0%)
#   adding: content/stable-diffusion/ldm/modules/losses/ (stored 0%)
#   adding: content/stable-diffusion/ldm/modules/losses/vqperceptual.py (deflated 74%)
#   adding: content/stable-diffusion/ldm/modules/losses/__init__.py (stored 0%)
#   adding: content/stable-diffusion/ldm/modules/losses/contperceptual.py (deflated 76%)
#   adding: content/stable-diffusion/ldm/modules/__pycache__/ (stored 0%)
#   adding: content/stable-diffusion/ldm/modules/__pycache__/x_transformer.cpython-310.pyc (deflated 52%)
#   adding: content/stable-diffusion/ldm/modules/__pycache__/attention.cpython-310.pyc (deflated 53%)
#   adding: content/stable-diffusion/ldm/modules/__pycache__/ema.cpython-310.pyc (deflated 45%)
#   adding: content/stable-diffusion/ldm/modules/ema.py (deflated 68%)
#   adding: content/stable-diffusion/ldm/util.py (deflated 62%)
#   adding: content/stable-diffusion/models/ (stored 0%)
#   adding: content/stable-diffusion/models/first_stage_models/ (stored 0%)
#   adding: content/stable-diffusion/models/first_stage_models/vq-f8/ (stored 0%)
#   adding: content/stable-diffusion/models/first_stage_models/vq-f8/config.yaml (deflated 57%)
#   adding: content/stable-diffusion/models/first_stage_models/kl-f8/ (stored 0%)
#   adding: content/stable-diffusion/models/first_stage_models/kl-f8/config.yaml (deflated 57%)
#   adding: content/stable-diffusion/models/first_stage_models/vq-f16/ (stored 0%)
#   adding: content/stable-diffusion/models/first_stage_models/vq-f16/config.yaml (deflated 57%)
#   adding: content/stable-diffusion/models/first_stage_models/vq-f4/ (stored 0%)
#   adding: content/stable-diffusion/models/first_stage_models/vq-f4/config.yaml (deflated 54%)
#   adding: content/stable-diffusion/models/first_stage_models/kl-f4/ (stored 0%)
#   adding: content/stable-diffusion/models/first_stage_models/kl-f4/config.yaml (deflated 56%)
#   adding: content/stable-diffusion/models/first_stage_models/vq-f8-n256/ (stored 0%)
#   adding: content/stable-diffusion/models/first_stage_models/vq-f8-n256/config.yaml (deflated 56%)
#   adding: content/stable-diffusion/models/first_stage_models/kl-f16/ (stored 0%)
#   adding: content/stable-diffusion/models/first_stage_models/kl-f16/config.yaml (deflated 58%)
#   adding: content/stable-diffusion/models/first_stage_models/vq-f4-noattn/ (stored 0%)
#   adding: content/stable-diffusion/models/first_stage_models/vq-f4-noattn/config.yaml (deflated 54%)
#   adding: content/stable-diffusion/models/first_stage_models/kl-f32/ (stored 0%)
#   adding: content/stable-diffusion/models/first_stage_models/kl-f32/config.yaml (deflated 58%)
#   adding: content/stable-diffusion/models/ldm/ (stored 0%)
#   adding: content/stable-diffusion/models/ldm/layout2img-openimages256/ (stored 0%)
#   adding: content/stable-diffusion/models/ldm/layout2img-openimages256/config.yaml (deflated 64%)
#   adding: content/stable-diffusion/models/ldm/text2img256/ (stored 0%)
#   adding: content/stable-diffusion/models/ldm/text2img256/config.yaml (deflated 64%)
#   adding: content/stable-diffusion/models/ldm/bsr_sr/ (stored 0%)
#   adding: content/stable-diffusion/models/ldm/bsr_sr/config.yaml (deflated 67%)
#   adding: content/stable-diffusion/models/ldm/lsun_beds256/ (stored 0%)
#   adding: content/stable-diffusion/models/ldm/lsun_beds256/config.yaml (deflated 63%)
#   adding: content/stable-diffusion/models/ldm/semantic_synthesis512/ (stored 0%)
#   adding: content/stable-diffusion/models/ldm/semantic_synthesis512/config.yaml (deflated 65%)
#   adding: content/stable-diffusion/models/ldm/ffhq256/ (stored 0%)
#   adding: content/stable-diffusion/models/ldm/ffhq256/config.yaml (deflated 63%)
#   adding: content/stable-diffusion/models/ldm/cin256/ (stored 0%)
#   adding: content/stable-diffusion/models/ldm/cin256/config.yaml (deflated 65%)
#   adding: content/stable-diffusion/models/ldm/inpainting_big/ (stored 0%)
#   adding: content/stable-diffusion/models/ldm/inpainting_big/config.yaml (deflated 63%)
#   adding: content/stable-diffusion/models/ldm/celeba256/ (stored 0%)
#   adding: content/stable-diffusion/models/ldm/celeba256/config.yaml (deflated 63%)
#   adding: content/stable-diffusion/models/ldm/lsun_churches256/ (stored 0%)
#   adding: content/stable-diffusion/models/ldm/lsun_churches256/config.yaml (deflated 65%)
#   adding: content/stable-diffusion/models/ldm/semantic_synthesis256/ (stored 0%)
#   adding: content/stable-diffusion/models/ldm/semantic_synthesis256/config.yaml (deflated 64%)
#   adding: content/stable-diffusion/setup.py (deflated 39%)
